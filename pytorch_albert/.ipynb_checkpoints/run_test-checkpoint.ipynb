# %%
# coding: UTF-8
import time
import torch
import numpy as np
from train_eval_transformer import train,test
from importlib import import_module
from utils import build_dataset, build_iterator, get_time_dif

if __name__ == '__main__':
    dataset = 'dataset'  # 数据集
    model_name = 'albert'  # bert
    x = import_module(model_name)
    config = x.Config(dataset)
    np.random.seed(1)
    torch.manual_seed(1)
    torch.cuda.manual_seed_all(1)
    torch.backends.cudnn.deterministic = True  # 保证每次结果一样

    start_time = time.time()
    print("Loading data...")
    train_data, dev_data, test_data = build_dataset(config)
    train_iter = build_iterator(train_data, config)
    dev_iter = build_iterator(dev_data, config)
    test_iter = build_iterator(test_data, config)
    time_dif = get_time_dif(start_time)
    print("Time usage:", time_dif)
    # train
    model = config.model.to(config.device)
    train(config, model, train_iter, dev_iter, test_iter)
    #test
    test(config, test_iter)
# Out:
# Some weights of the model checkpoint at ./albert_pretrain were not used when initializing AlbertForSequenceClassification: ['predictions.bias', 'predictions.LayerNorm.weight', 'predictions.LayerNorm.bias', 'predictions.dense.weight', 'predictions.dense.bias', 'predictions.decoder.weight', 'predictions.decoder.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at ./albert_pretrain and are newly initialized: ['albert.pooler.weight', 'albert.pooler.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 247it [00:00, 2467.89it/s]
# Loading data...
# 96456it [00:39, 2429.08it/s]
# 12051it [00:04, 2458.33it/s]
# 12060it [00:05, 2053.22it/s]
# Time usage: 0:00:50
# Epoch [1/3]
# ---------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-1-e0d8897baf15> in <module>
#      27     # train
#      28     model = config.model.to(config.device)
# ---> 29     train(config, model, train_iter, dev_iter, test_iter)
#      30     #test
#      31     test(config, test_iter)
#
# ~/TextClass/albert_model/albert_v2.0/train_eval_transformer.py in train(config, model, train_iter, dev_iter, test_iter)
#      60                 labels = b_labels.data.cpu()
#      61                 train_acc = metrics.accuracy_score(labels, predic)
# ---> 62                 dev_acc, dev_loss = evaluate(config, model, dev_iter)
#      63                 if dev_loss < dev_best_loss:
#      64                     dev_best_loss = dev_loss
#
# ~/TextClass/albert_model/albert_v2.0/train_eval_transformer.py in evaluate(config, model, data_iter, test)
#     119                             token_type_ids=None,
#     120                             attention_mask=b_input_mask,
# --> 121                             labels=b_labels)
#     122             loss = outputs.loss
#     123             loss_total += loss.item()
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/transformers/models/albert/modeling_albert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     989             output_attentions=output_attentions,
#     990             output_hidden_states=output_hidden_states,
# --> 991             return_dict=return_dict,
#     992         )
#     993
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/transformers/models/albert/modeling_albert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     692             output_attentions=output_attentions,
#     693             output_hidden_states=output_hidden_states,
# --> 694             return_dict=return_dict,
#     695         )
#     696
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/transformers/models/albert/modeling_albert.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     441                 head_mask[group_idx * layers_per_group : (group_idx + 1) * layers_per_group],
#     442                 output_attentions,
# --> 443                 output_hidden_states,
#     444             )
#     445             hidden_states = layer_group_output[0]
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/transformers/models/albert/modeling_albert.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states)
#     390
#     391         for layer_index, albert_layer in enumerate(self.albert_layers):
# --> 392             layer_output = albert_layer(hidden_states, attention_mask, head_mask[layer_index], output_attentions)
#     393             hidden_states = layer_output[0]
#     394
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/transformers/models/albert/modeling_albert.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states)
#     364             self.chunk_size_feed_forward,
#     365             self.seq_len_dim,
# --> 366             attention_output[0],
#     367         )
#     368         hidden_states = self.full_layer_layer_norm(ffn_output + attention_output[0])
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/transformers/modeling_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#    1698         return torch.cat(output_chunks, dim=chunk_dim)
#    1699
# -> 1700     return forward_fn(*input_tensors)
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/transformers/models/albert/modeling_albert.py in ff_chunk(self, attention_output)
#     373         ffn_output = self.ffn(attention_output)
#     374         ffn_output = self.activation(ffn_output)
# --> 375         ffn_output = self.ffn_output(ffn_output)
#     376         return ffn_output
#     377
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# ~/env_py_others/tf_2.3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
# -> 1692         output = input.matmul(weight.t())
#    1693         if bias is not None:
#    1694             output += bias
#
# KeyboardInterrupt:
